# %% [markdown]
# # Day 6: 23 Feb Monday
#
# ### Brief Overview of List, Tuple, Dictionary, Set, Loops (While loop, For Loop),
#
# ### Function with (Paramenter or without Parameter) or Argument

# %% [markdown]
# ### Function has three components:
#
# ### 1.Func Name              2.Func Body               3.Func call krna
#
# ### Function has Two Types:
#
# ### 1.Pre-Defined                     2.User-Defined

# %% [markdown]
# ### Lambda Function
#
# #### (tb hi use ho ga jb one line ma function call krna ho ga)

# %% [markdown]
# # Task: Calculator

# %%
while True:
    try:
        num1 = int(input("Enter First number:"))
        num2 = int(input("Enter Second number:"))
        break
    except ValueError:
        print("Invalid input! Please enter numbers only.")
        exit()
operator = input("Enter operator(+, -, *, /):")
if operator == "+":
    print("Result:", num1 + num2)
elif operator == "-":
    print("Result:", num1 - num2)
elif operator == "*":
    print("Result:", num1 * num2)
elif operator == "/":
    if num2 == 0:
        print("can't divisible by zero")
    else:
        print("Result:", num1 / num2)
else:
    print("Invalid operator")
# Out:
# Enter First number: x
# Invalid input! Please enter numbers only.
# Enter First number: 45
# Enter Second number: 54
# Enter operator(+, -, *, /): /
# Result: 0.8333333333333334

# %% [markdown]
# # Task: Electricity billing system according to units

# %%
units = float(input("Enter your electricity units:"))

if units<=100:
    price = 5
elif units<=200:
    price = 8
elif units <=300:
    price = 10
else:
    price = 15

bill = units * price
tax = bill * 10
total = bill + tax

print("Electricity bill:", bill)
print("Tax", tax)
print("Total bill", total)
# Out:
# Enter your electricity units: 126
# Electricity bill: 1008.0
# Tax 10080.0
# Total bill 11088.0
