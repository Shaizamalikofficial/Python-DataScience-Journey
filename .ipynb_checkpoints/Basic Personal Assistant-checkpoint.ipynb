# %% [markdown]
# ### Task: Create a simple program that acts as a basic personal assistant by asking for user input
# ### and performing simple operations.

# %%
# Ask the user for their name and store it in a variable
name = input("What is youre name?")

# Ask the user for their birth-year and store it
birth_year = int(input("What year were you born?"))

# Ask the user for their current age and store it
current_age = int(input("What is your current age?"))

# Get the current year
current_year = 2026

# Calculate the year when user will turn 100
year_when_100 = current_year + (100 - age)

# Ask the user for a lucky no and convet it into float
lucky_number = float(input("What is your lucky number?"))

# Print a summary message with all information
print("\n Persnal Assistant Summary")
print("Hello", name + '!')
print("You were born in", birth_year, ".")
print("You are currently", age, "years old.")
print("You will turn 100 in the year", year_when_100, ".")
print("Your lucky number is", lucky_number, ".")
# Out:
# What is youre name? Ameera
# What year were you born? 2010
# What is your current age? 16
# What is your lucky number? 7
#  Persnal Assistant Summary
# Hello Ameera!
# You were born in 2010 .
# You are currently 18 years old.
# You will turn 100 in the year 2108 .
# Your lucky number is 7.0 .
