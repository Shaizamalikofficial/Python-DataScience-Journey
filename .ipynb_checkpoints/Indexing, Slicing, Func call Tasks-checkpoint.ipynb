# %% [markdown]
# # Day 2: (Tuesday 17 feb)
# Indexing(+ve, -ve), Slicing(+ve, -ve), Function calling (append, remove, repeat, replace, insert, len, upper, lower), Comments , Type casting

# %% [markdown]
# ## Assignment Task

# %% [markdown]
# ### Name: Shaiza Malik

# %%
##Task1:Print any integer number
print("integer number is:", 20)
# Out:
# integer number is: 20

# %%
##Task2: Print a floating‑point number
print("floating-point number is:", 58.5)
# Out:
# floating-point number is: 58.5

# %%
##Task3:Print a Boolean value
print("boolean value is:", True)
# Out:
# boolean value is: True

# %%
##Task4: Store your age in a variable and print it
age = 19
print (age)
# Out:
# 19

# %%
##Task5: Add two numbers and print result
d = 10
b = 20
add = d + b
print (add)
# Out:
# 30

# %%
##Task6: Multiply two numbers
x = 4
y = 5
multiply = x*y
print (multiply)
# Out:
# 20

# %%
##Task7: Compare two numbers using > operator
a = 7
b = 9
if a > b:
    print('a is greater than b')
else: 
    print('a is smaller than b')
# Out:
# a is smaller than b

# %%
##Task8: Create a string variable with your name
Name = "Shaiza Malik"
print(Name)
# Out:
# Shaiza Malik

# %%
##Task9: Print sum of 3 + 7 * 2
sum = 3 + 7 * 2
print (sum)
# Out:
# 17

# %%
##Task10: Check if 10 equals 10
num = 10
if 10 == 10:
    print("10 equals 10")
else:
    print(10 != 10)
# Out:
# 10 equals 10

# %%
##Task11: Create a string "Python"
string = "Python Programming"
print (string)
# Out:
# Python Programming

# %%
##Task12: Concatenate your name with " Khan"
name = "Shaiza"
print(name + "" + " Khan")
# Out:
# Shaiza Khan

# %%
##Task13: Repeat a string 3 times
string = "Python Developer"
print(string * 3)
# Out:
# Python DeveloperPython DeveloperPython Developer

# %%
##Task14: Print first character of a string
variable = "Artificial Intelligence"
print (variable[0])
# Out:
# A

# %%
##Task15: Slice first 4 characters
v = "Machine Learning"
print(v[0:4])
# Out:
# Mach

# %%
##Task16: Find length of string
str = "Welcome to Python Programming"
print(len(str))
# Out:
# 29

# %%
##Task17: Convert string to lowercase
str = "Welcome to Python Programming"
print (str.lower())
# Out:
# welcome to python programming

# %%
##Task18: Convert string to uppercase
str = "Welcome to Python Programming"
print (str.upper())
# Out:
# WELCOME TO PYTHON PROGRAMMING

# %%
##Task19: Replace one word with another
var = "I am Ayesha"
print(var.replace("Ayesha", "Shaiza"))
# Out:
# I am Shaiza

# %%
##Task20: Check if substring exists
string = "I love Python Programming"
substring = "Python"
if substring in string:
    print("substring exists")
else:
    print("substring does not exist")
# Out:
# substring exists

# %%
##Task21:  Take name input from user
name = input("Please enter your name:")
print ("You Entered:", name)
# Out:
# Please enter your name: Shaiza
# You Entered: Shaiza

# %%
##Task22: Take age input and convert to int
age = input("Enter you age")
age_float = float(age)
age_int = int(age_float)
print("You entered:", age_int)
# Out:
# Enter you age 18.8
# You entered: 18

# %%
##Task23: Take decimal input and convert to float
num = input("Enter a decimal number:")
num_float = float(num)
print("You entered:", num_float)
# Out:
# Enter a decimal number: 4
# You entered: 4.0

# %%
##Task 24: Convert string "100" to integer
string = "100"
integer = int(string)
print(integer)
# Out:
# 100

# %%
##Task 25: Convert number 50 to string
number = 50
string = str(number)
print(string)
print(type(string))
# Out:
# 50
# <class 'str'>

# %%
##Task26 Write a single‑line comment

  ### Its me Shaiza, a Dedicated Learner of Python Programming.

# %%
##Task27: Add two input numbers
num1 = int(input("First number:"))
num2 = int(input("Second number:"))
sum = num1 + num2 
print(sum)
# Out:
# First number: 20
# Second number: 10
# 30

# %%
##Task28: Convert 0 to Boolean
no = 0
bol = bool(no)
print(bol)
# Out:
# False

# %%
##Task29: Convert 1 to Boolean
Num = 1
bol = bool(Num)
print(bol)
# Out:
# True

# %%
##Task30: Print greeting using input name
input_name = input("Enter your name:")
print("Hey", input_name +""+ " Welcome to Anaconda Workspace")
# Out:
# Enter your name: Shaiza
# Hey Shaiza Welcome to Anaconda Workspace

# %%
## append func in list
list1 = [1,2,3,4,5]
list1.append(6)
print(list1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
## insert func in list2
list2 = [2,4,6,8]
list2.insert(4, 10)
print(list2)
# Out:
# [2, 4, 6, 8, 10]
